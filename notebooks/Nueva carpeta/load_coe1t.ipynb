# %%
import pandas as pd
import missingno as msno
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Vivienda

# %%
file = "../../data/enh/vivienda.csv"

# %%
df = pd.read_csv(file)
# Out:
# C:\Users\aniit\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad  cocina  \
# 0  10000601        1          8           9         3                  1
# 1  10000602        1          8           9         3         25       1
# 2  10000603        1          8           9         3                  1
# 3  10000604        1          8           9         3                  1
# 4  10000605        1          8           9         3         40       1
#
#   cocina_dor  cuart_dorm  num_cuarto     ...      dispos_ne tot_resid  \
# 0          2           2           4     ...                        2
# 1          2           1           8     ...                        2
# 2          2           4           9     ...                        8
# 3          2           2           6     ...                        4
# 4          2           2           3     ...                        3
#
#    tot_hog ubica_geo   ageb tam_loc est_socio est_dis  upm  factor_viv
# ...

# %%
df.shape
# Out:
# (58615, 85)

# %% [markdown]
# coe1t215

# %%
file = "../../dataframes/enoe/coe1t215_clean.csv"

# %%
df_coe1t215 = pd.read_csv(file)

# %%
df_coe1t215.head()
# Out:
#    Unnamed: 0  r_def  cd_a  ent    con     upm  d_sem  n_pro_viv  v_sel  \
# 0           0      0     1    9  40001  900471    101         15      1
# 1           1      0     1    9  40001  900471    101         15      1
# 2           2      0     1    9  40001  900471    101         38      2
# 3           3      0     1    9  40002  900821    101         24      1
# 4           4      0     1    9  40001  900471    101         15      1
#
#    n_hog ...   per  n_ren  eda  n_inf  p1  ur  fac     id  mun  loc
# 0      1 ...   215      1   46      4   1   1  426  40014    2    1
# 1      1 ...   215      2   47      4   1   1  426  40015    2    1
# 2      1 ...   215      1   35      2   1   1  426  40015    2    1
# 3      1 ...   215      1   30      1   2   1  833  40015    2    1
# 4      1 ...   215      3   22      4   1   1  426  40016    2    1
#
# [5 rows x 22 columns]

# %%
df_coe1t215.shape
# Out:
# (49034, 22)

# %% [markdown]
# coe1t315

# %%
file = "../../dataframes/enoe/coe1t315_clean.csv"

# %%
df_coe1t315 = pd.read_csv(file)

# %%
df_coe1t315.head()
# Out:
#    Unnamed: 0  r_def  cd_a  ent    con     upm  d_sem  n_pro_viv  v_sel  \
# 0           0      0     1    9  40001  900471    101         15      1
# 1           1      0     1    9  40001  900471    101         15      1
# 2           2      0     1    9  40001  900471    101         38      2
# 3           3      0     1    9  40002  900821    101         24      1
# 4           4      0     1    9  40001  900471    101         15      1
#
#    n_hog ...   per  n_ren  eda  n_inf  p1  ur  fac     id  mun  loc
# 0      1 ...   315      1   46      1   1   1  425  40014    2    1
# 1      1 ...   315      2   47      1   1   1  425  40015    2    1
# 2      1 ...   315      1   35      1   1   1  425  40015    2    1
# 3      1 ...   315      1   30      1   2   1  834  40015    2    1
# 4      1 ...   315      3   22      1   1   1  425  40016    2    1
#
# [5 rows x 22 columns]

# %%
df_coe1t315.shape
# Out:
# (49485, 22)

# %% [markdown]
# coe1t415

# %%
file = "../../dataframes/enoe/coe1t415_clean.csv"

# %%
df_coe1t415 = pd.read_csv(file)

# %%
df_coe1t415.head()
# Out:
#    Unnamed: 0  r_def  cd_a  ent    con     upm  d_sem  n_pro_viv  v_sel  \
# 0           0      0     1    9  40001  900471    101         15      1
# 1           1      0     1    9  40001  900471    101         15      1
# 2           2      0     1    9  40001  900471    101         38      2
# 3           3      0     1    9  40002  900821    101         24      1
# 4           4      0     1    9  40001  900471    101         15      1
#
#    n_hog ...   per  n_ren  eda  n_inf  p1  ur  fac     id  mun  loc
# 0      1 ...   415      1   46      4   1   1  426  40014    2    1
# 1      1 ...   415      2   48      4   1   1  426  40015    2    1
# 2      1 ...   415      1   35      2   1   1  426  40015    2    1
# 3      1 ...   415      1   31      1   2   1  835  40015    2    1
# 4      1 ...   415      3   22      4   1   1  426  40016    2    1
#
# [5 rows x 22 columns]

# %%
df_coe1t415.shape
# Out:
# (47111, 22)

# %%
frames = [df_coe1t115, df_coe1t215, df_coe1t315, df_coe1t415]
df = pd.concat(frames)

# %%
df.shape
# Out:
# (195693, 22)

# %%
df_copy = df.copy()

# %% [markdown]
# ## Check NA

# %%
df_copy.isnull().any().any()
# Out:
# False

# %%
file = "../../dataframes/enoe/coe1t.csv"

# %%
df_copy.to_csv(file)

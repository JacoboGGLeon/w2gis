# %%
import pandas as pd

# %%
df = pd.read_csv(filepath_or_buffer="../../../../Downloads/inegi/inegi/ENH/enh_impute_check.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  aire_acond  antiguedad  bano_comp  bano_excus  bano_regad  \
# 0           0           2          30          2           0           0
# 1           1           2          30          2           0           0
# 2           2           2          42          2           0           0
# 3           3           2          42          2           0           0
# 4           4           2          26          2           1           0
#
#    bomba_agua  calefacc  calentador  chimenea   ...     tot_hom  tot_integ  \
# 0           1         2           1         2   ...           3          4
# 1           1         2           1         2   ...           2          6
# 2           1         2           2         2   ...           3          4
# 3           1         2           2         2   ...           2          6
# 4           1         2           1         2   ...           3          4
#
#    tot_muj  celular  tel_fijo  tv_paga  año  CVE_ENT  CVE_MUN  CVE_LOC
# ...

# %%
df[(df.CVE_ENT == 9 )].shape
# Out:
# (8239, 60)

# %%
df[(df.CVE_ENT == 9 )].to_csv("C:/Users/aniit/Desktop/w2gis/dataframes/enh_09.csv")

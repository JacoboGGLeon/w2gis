# %%
import pandas as pd
import missingno as msno
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## percepción sobre seguridad y desempeño institucional

# %%
file = "../../data/envipe/TPer_Vic1.csv"

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Unnamed: 0            ID_PER     UPM  VIV_SEL  HOGAR RESUL_H  R_SEL  AREAM  \
# 0           0  0100006.01.01.01  100006        1      1       B      1   14.0
# 1           1  0100006.02.01.02  100006        2      1       A      2   14.0
# 2           2  0100006.03.01.01  100006        3      1       A      1   14.0
# 3           3  0100006.04.01.02  100006        4      1       A      2   14.0
# 4           4  0100006.05.01.01  100006        5      1       B      1   14.0
#
#    AP4_1  AP4_2_01     ...      AP5_6_10  AP5_8  FAC_HOG  FAC_ELE  EST_DIS  \
# 0      3         1     ...           NaN      4      172      516        5
# 1      3         0     ...           NaN      4      172      344        5
# 2      3         0     ...           NaN      4      172      344        5
# 3      1         0     ...           NaN      3      172      344        5
# 4      2         0     ...           NaN      1      172      172        5
#
#    UPM_DIS  DOMINIO  ESTRATO  FAC_HOG_AM  FAC_ELE_AM
# 0        1        U        3         173         519
# 1        1        U        3         173         346
# 2        1        U        3         173         346
# 3        1        U        3         173         346
# 4        1        U        3         173         173
#
# [5 rows x 169 columns]

# %%
df.shape
# Out:
# (84507, 169)

# %%
df_copy = df.copy()

# %%
df_copy.columns
# Out:
# Index(['Unnamed: 0', 'ID_PER', 'UPM', 'VIV_SEL', 'HOGAR', 'RESUL_H', 'R_SEL',
#        'AREAM', 'AP4_1', 'AP4_2_01',
#        ...
#        'AP5_6_10', 'AP5_8', 'FAC_HOG', 'FAC_ELE', 'EST_DIS', 'UPM_DIS',
#        'DOMINIO', 'ESTRATO', 'FAC_HOG_AM', 'FAC_ELE_AM'],
#       dtype='object', length=169)

# %% [markdown]
# ## Check NA

# %%
df_copy.isnull().any().any()
# Out:
# True

# %%
df_copy.columns[df_copy.isnull().any()]
# Out:
# Index(['AREAM', 'AP4_9_1', 'AP4_9_2', 'AP4_9_3', 'AP4_9_4', 'AP4_9_5',
#        'AP4_9_6', 'AP4_12', 'AP5_4_01', 'AP5_5_01', 'AP5_6_01', 'AP5_7_1',
#        'AP5_4_02', 'AP5_5_02', 'AP5_6_02', 'AP5_7_2', 'AP5_4_03', 'AP5_5_03',
#        'AP5_6_03', 'AP5_7_3', 'AP5_4_04', 'AP5_5_04', 'AP5_6_04', 'AP5_7_4',
#        'AP5_4_05', 'AP5_5_05', 'AP5_6_05', 'AP5_4_06', 'AP5_5_06', 'AP5_6_06',
#        'AP5_4_07', 'AP5_5_07', 'AP5_6_07', 'AP5_4_08', 'AP5_5_08', 'AP5_6_08',
#        'AP5_4_09', 'AP5_5_09', 'AP5_6_09', 'AP5_4_10', 'AP5_5_10', 'AP5_6_10'],
#       dtype='object')

# %%
len(pd.isnull(df_copy).any(1).nonzero()[0].tolist())
# Out:
# 84382

# %%
df_copy.replace(to_replace=' ', value=np.NaN, inplace=True)

# %%
msno.bar(df_copy)
plt.savefig('../../images/pre_load_bar_TPer_Vic1.png')

# %%
df_copy.fillna(value=-1, inplace=True)

# %%
threshold = round(df_copy.shape[0]*.8)
threshold
# Out:
# 67606

# %%
l = []
for column in df_copy.columns:
    na_column =  df_copy[column].value_counts().get(-1)
    if(na_column != None):
        #print(column, ': ', df_copy.shape[0] - na_column, ' - ', threshold)
        if (df_copy.shape[0] - na_column < threshold):
            #print(column, ': ', 'd e l e t e d')
            l.append(column)

# %%
df_copy.shape
# Out:
# (84507, 169)

# %%
len(l)
# Out:
# 41

# %%
df_copy.drop(labels=l, axis=1, inplace=True)

# %%
df_copy.replace(to_replace=-1, value=np.NaN, inplace=True)

# %%
msno.bar(df_copy)
plt.savefig('../../images/post_load_bar_TPer_Vic1.png')

# %%
df_copy.isnull().any().any()
# Out:
# True

# %%
df_copy.shape
# Out:
# (84507, 128)

# %%
file = "../../dataframes/TPer_Vic1.csv"

# %%
df_copy.to_csv(file)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Vivienda

# %%
file = "../../dataframes/enoe/enoe_transf_2016.csv"

# %%
df = pd.read_csv(filepath_or_buffer=file)

# %%
df.shape
# Out:
# (313968, 75)

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.head()
# Out:
#    Unnamed: 0      est    t_loc       sex   l_nac_c    cs_p12  cs_p13_1  \
# 0           0  0.12986  0.59414  0.522846  0.052368  0.960063  0.158357
# 1           1  0.12986  0.59414  0.477154  0.052368  0.960063  0.158357
# 2           2  0.12986  0.59414  0.522846  0.040307  0.960063  0.179123
# 3           3  0.12986  0.59414  0.522846  0.052368  0.960063  0.158357
# 4           4  0.12986  0.59414  0.477154  0.052368  0.960063  0.263259
#
#    cs_p13_2    cs_p17     e_con ...   nac_mes  nac_anio  anios_esc  hrsocup  \
# 0  0.069450  0.796963  0.369668 ...       8.0    1987.0         16       40
# 1  0.069450  0.796963  0.131564 ...       2.0    1969.0         16       24
# 2  0.124681  0.796963  0.131564 ...       9.0    1966.0         11       32
# 3  0.069450  0.203030  0.369668 ...      10.0    1990.0         16        0
# 4  0.162634  0.796963  0.402818 ...       6.0    1960.0          6       45
#
#    ingocup  ing_x_hrs  t_tra  ent  mun  loc
# 0        0    0.00000      1    9    2    1
# 1     6000   58.13953      2    9    2    1
# 2     4300   31.25000      1    9    2    1
# 3        0    0.00000      1    9    2    1
# 4        0    0.00000      1    9    2    1
#
# [5 rows x 75 columns]

# %%
df_copy = df.copy()

# %%
df_copy.drop(labels=['Unnamed: 0'], axis=1, inplace=True)

# %%
df_copy.columns
# Out:
# Index(['tipo_viv', 'mat_pared', 'mat_techos', 'mat_pisos', 'ais_techos',
#        'ais_pared', 'ais_ventan', 'ais_otro', 'cocina_dor', 'disp_agua',
#        'dotac_agua', 'uso_compar', 'sanit_agua', 'drenaje', 'disp_elect',
#        'combustible', 'eli_basura', 'lavadero', 'fregadero', 'regadera',
#        'rega_elect', 'tinaco_azo', 'cisterna', 'pileta', 'calent_sol',
#        'calent_gas', 'medidor_luz', 'bomba_agua', 'tanque_gas', 'aire_acond',
#        'calefacc', 'chimenea', 'repar_pard', 'repar_tech', 'repar_agua',
#        'repar_dren', 'repar_cabl', 'const_dorm', 'const_coci', 'const_bano',
#        'const_neg', 'tenencia', 'computador', 'tel_fijo', 'celular',
#        'internet', 'tv_paga', 'auto_pick', 'ent', 'mun', 'loc', 'cuart_dorm',
#        'num_cuarto', 'bano_comp', 'bano_excus', 'bano_regad', 'focos_inca',
#        'focos_ahor', 'tot_resid', 'tot_hog', 'tam_loc', 'est_socio'],
#       dtype='object')

# %%
numericos = ['cuart_dorm', 'num_cuarto', 'bano_comp', 'bano_excus', 'bano_regad', 'focos_inca', 
             'focos_ahor', 'tot_resid', 'tot_hog' ,'tam_loc', 'est_socio']

# %%
len(numericos)
# Out:
# 11

# %%
categoricos = []

for row in df_copy.columns:
    if row not in numericos:
        if (row != 'ent') & (row != 'mun') & (row != 'loc') :
#            print(row)
            categoricos.append(row)
            
categoricos
# Out:
# ['tipo_viv',
#  'mat_pared',
#  'mat_techos',
#  'mat_pisos',
#  'ais_techos',
#  'ais_pared',
#  'ais_ventan',
#  'ais_otro',
#  'cocina_dor',
#  'disp_agua',
#  'dotac_agua',
#  'uso_compar',
#  'sanit_agua',
#  'drenaje',
#  'disp_elect',
#  'combustible',
#  'eli_basura',
#  'lavadero',
#  'fregadero',
#  'regadera',
#  'rega_elect',
#  'tinaco_azo',
#  'cisterna',
#  'pileta',
#  'calent_sol',
#  'calent_gas',
#  'medidor_luz',
#  'bomba_agua',
#  'tanque_gas',
#  'aire_acond',
#  'calefacc',
#  'chimenea',
#  'repar_pard',
#  'repar_tech',
#  'repar_agua',
#  'repar_dren',
#  'repar_cabl',
#  'const_dorm',
#  'const_coci',
#  'const_bano',
#  'const_neg',
#  'tenencia',
#  'computador',
#  'tel_fijo',
#  'celular',
#  'internet',
#  'tv_paga',
#  'auto_pick']

# %%
df_copy.shape
# Out:
# (50643, 62)

# %%
f = {}

for column in df_copy.columns:
#    print(column)
    if(column in df_copy[categoricos].columns):
#        print(column, 'categoricos')
        f[column] = lambda x: x.value_counts().index[0]
    elif(column in df_copy[numericos].columns):
#        print(column, 'numericos')
        f[column] = 'mean'
    
f
# Out:
# {'tipo_viv': <function __main__.<lambda>(x)>,
#  'mat_pared': <function __main__.<lambda>(x)>,
#  'mat_techos': <function __main__.<lambda>(x)>,
#  'mat_pisos': <function __main__.<lambda>(x)>,
#  'ais_techos': <function __main__.<lambda>(x)>,
#  'ais_pared': <function __main__.<lambda>(x)>,
#  'ais_ventan': <function __main__.<lambda>(x)>,
#  'ais_otro': <function __main__.<lambda>(x)>,
#  'cocina_dor': <function __main__.<lambda>(x)>,
#  'disp_agua': <function __main__.<lambda>(x)>,
#  'dotac_agua': <function __main__.<lambda>(x)>,
#  'uso_compar': <function __main__.<lambda>(x)>,
#  'sanit_agua': <function __main__.<lambda>(x)>,
#  'drenaje': <function __main__.<lambda>(x)>,
#  'disp_elect': <function __main__.<lambda>(x)>,
#  'combustible': <function __main__.<lambda>(x)>,
#  'eli_basura': <function __main__.<lambda>(x)>,
#  'lavadero': <function __main__.<lambda>(x)>,
#  'fregadero': <function __main__.<lambda>(x)>,
#  'regadera': <function __main__.<lambda>(x)>,
#  'rega_elect': <function __main__.<lambda>(x)>,
#  'tinaco_azo': <function __main__.<lambda>(x)>,
#  'cisterna': <function __main__.<lambda>(x)>,
#  'pileta': <function __main__.<lambda>(x)>,
#  'calent_sol': <function __main__.<lambda>(x)>,
#  'calent_gas': <function __main__.<lambda>(x)>,
#  'medidor_luz': <function __main__.<lambda>(x)>,
#  'bomba_agua': <function __main__.<lambda>(x)>,
#  'tanque_gas': <function __main__.<lambda>(x)>,
#  'aire_acond': <function __main__.<lambda>(x)>,
#  'calefacc': <function __main__.<lambda>(x)>,
#  'chimenea': <function __main__.<lambda>(x)>,
#  'repar_pard': <function __main__.<lambda>(x)>,
#  'repar_tech': <function __main__.<lambda>(x)>,
#  'repar_agua': <function __main__.<lambda>(x)>,
#  'repar_dren': <function __main__.<lambda>(x)>,
#  'repar_cabl': <function __main__.<lambda>(x)>,
#  'const_dorm': <function __main__.<lambda>(x)>,
#  'const_coci': <function __main__.<lambda>(x)>,
#  'const_bano': <function __main__.<lambda>(x)>,
#  'const_neg': <function __main__.<lambda>(x)>,
#  'tenencia': <function __main__.<lambda>(x)>,
#  'computador': <function __main__.<lambda>(x)>,
#  'tel_fijo': <function __main__.<lambda>(x)>,
#  'celular': <function __main__.<lambda>(x)>,
#  'internet': <function __main__.<lambda>(x)>,
#  'tv_paga': <function __main__.<lambda>(x)>,
#  'auto_pick': <function __main__.<lambda>(x)>,
#  'cuart_dorm': 'mean',
#  'num_cuarto': 'mean',
#  'bano_comp': 'mean',
#  'bano_excus': 'mean',
#  'bano_regad': 'mean',
#  'focos_inca': 'mean',
#  'focos_ahor': 'mean',
#  'tot_resid': 'mean',
#  'tot_hog': 'mean',
#  'tam_loc': 'mean',
#  'est_socio': 'mean'}

# %%
grouped = df_copy.groupby(by=['ent', 'mun', 'loc']).agg(f)

# %%
grouped
# Out:
#               tipo_viv  mat_pared  mat_techos  mat_pisos  ais_techos  \
# ent mun loc
# 1   1   1     0.954999   0.904291    0.790001   0.525107    0.942184
#         138   0.954999   0.060541    0.790001   0.461584    0.942184
#         144   0.954999   0.904291    0.790001   0.461584    0.942184
#         293   0.954999   0.904291    0.790001   0.461584    0.942184
#         429   0.954999   0.904291    0.790001   0.461584    0.942184
#         548   0.954999   0.904291    0.790001   0.461584    0.942184
#         707   0.954999   0.904291    0.790001   0.525107    0.942184
#         922   0.954999   0.904291    0.790001   0.461584    0.942184
#         1025  0.954999   0.904291    0.790001   0.525107    0.942184
#         1181  0.954999   0.904291    0.790001   0.461584    0.942184
#         2043  0.954999   0.904291    0.790001   0.461584    0.942184
#         2346  0.954999   0.904291    0.790001   0.525107    0.942184
#         2402  0.954999   0.904291    0.790001   0.461584    0.942184
#     2   1     0.954999   0.904291    0.790001   0.461584    0.942184
#         14    0.954999   0.904291    0.790001   0.461584    0.942184
#         34    0.954999   0.060541    0.790001   0.461584    0.942184
#         47    0.954999   0.904291    0.790001   0.461584    0.942184
#     3   1     0.954999   0.904291    0.790001   0.525107    0.942184
#         65    0.954999   0.904291    0.790001   0.461584    0.942184
#         171   0.954999   0.904291    0.790001   0.461584    0.942184
#     4   1     0.954999   0.904291    0.790001   0.461584    0.942184
#         32    0.954999   0.060541    0.790001   0.461584    0.942184
#     5   1     0.954999   0.904291    0.790001   0.525107    0.942184
#         41    0.954999   0.904291    0.790001   0.525107    0.942184
#         66    0.954999   0.904291    0.790001   0.461584    0.942184
#         78    0.954999   0.904291    0.790001   0.525107    0.942184
#         82    0.954999   0.904291    0.790001   0.525107    0.942184
#         84    0.954999   0.904291    0.790001   0.461584    0.942184
#         105   0.954999   0.904291    0.790001   0.525107    0.942184
#         109   0.954999   0.904291    0.790001   0.461584    0.942184
# ...                ...        ...         ...        ...         ...
# 32  40  6     0.954999   0.060541    0.790001   0.461584    0.942184
#         10    0.954999   0.060541    0.790001   0.461584    0.942184
#         17    0.954999   0.060541    0.109512   0.461584    0.942184
#         24    0.954999   0.060541    0.109512   0.461584    0.942184
#         33    0.954999   0.060541    0.790001   0.461584    0.942184
#     41  3     0.954999   0.060541    0.790001   0.461584    0.942184
#         7     0.954999   0.060541    0.790001   0.461584    0.942184

# %%
import pandas as pd
import missingno as msno
import numpy as np
# %matplotlib inline
# Out:
# C:\Users\aniit\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %% [markdown]
# ## Vivienda

# %%
file = "../../data/enh/vivienda.csv"

# %%
df = pd.read_csv(file)
# Out:
# C:\Users\aniit\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (58615, 85)

# %%
df_copy=df.copy()

# %% [markdown]
# ## Check NA

# %%
df_copy.isnull().any().any()
# Out:
# False

# %%
["folioviv", ]

# %%
df_copy.replace(to_replace='&', value=np.nan, inplace=True)

# %%
df_copy.replace(to_replace=' ', value=np.nan, inplace=True)

# %%
for column in df_copy.columns:
    print(column, ': ', df_copy[column].unique())
# Out:
# folioviv :  [ 10000601  10000602  10000603 ... 326079218 326079219 326079220]
# tipo_viv :  ['1' '2' '3' '5' nan '4' 1 5 2 3]
# mat_pared :  [8 7 6 1 3 5 2 4]
# mat_techos :  [9 7 3 1 4 6 2 8 5]
# mat_pisos :  ['3' '2' '1' nan 2 3 1]
# antiguedad :  [nan '25' '40' '44' '30' '33' '22' '3' '20' '42' '16' '36' '50' '78' '12'
#  '70' '65' '45' '55' '5' '60' '35' '32' '15' '7' '56' '62' '74' '99' '52'
#  '14' '26' '24' '10' '23' '9' '34' '6' '1' '27' '28' '29' '39' '31' '47'
#  '18' '80' '4' '2' '38' '11' '17' '13' '19' '8' '37' '21' '0' '48' '57'
#  '64' '85' '84' '46' '95' '51' '43' '58' '83' '75' '67' '82' '41' '49'
#  '90' '63' '54' '53' '68' '77' '59' '98' '73' '86' '69' '71' '72' '61'
#  '87' '88' '76' '66' '81' '79']
# cocina :  [1 2]
# cocina_dor :  ['2' '1' nan]
# cuart_dorm :  [ 2  1  4  3  5  6  7  8 10]
# num_cuarto :  [ 4  8  9  6  3  5  7  2 12 10  1 11 13 15 16 14]
# disp_agua :  [1 2 4 5 6 3]
# dotac_agua :  ['1' nan '2' '4' '3' '5']
# excusado :  [1 2]
# uso_compar :  ['2' '1' nan]
# sanit_agua :  ['1' '2' nan '3']
# bano_comp :  ['1' '4' '2' '3' '0' '5' nan '6' '7' '8' '9']
# bano_excus :  ['0' '1' '2' nan '3' '8' '9' '4' '6' '5']
# bano_regad :  ['0' '1' '2' nan '8' '9' '3' '4']
# drenaje :  [1 4 2 5 3]
# disp_elect :  [1 5 4 3 2]
# potencia :  [nan '-1' '12' '999' '135' '100' '800' '103' '65' '50' '20' '45' '130'
#  '250' '150' '90' '600' '120' '60' '15' '500' '75' '30' '400' '145' '4'
#  '55']
# focos_inca :  ['4' '20' '0' '11' '12' '3' '1' '6' '9' '5' '7' '2' '10' '25' '8' '15'
#  '13' '30' '14' '19' nan '17' '31' '22' '50' '16' '23' '99' '26' '21' '98'
#  '29' '60' '18' '27' '33' '32' '35' '65' '24' '39' '80' '40' '28' '45']
# focos_ahor :  ['4' '0' '15' '13' '8' '11' '21' '10' '7' '16' '18' '12' '20' '3' '6' '26'
#  '38' '9' '14' '2' '5' '1' '17' '35' '19' '22' '25' '75' '30' '32' '40'
#  '23' '24' '27' nan '39' '50' '36' '60' '55' '28' '82' '64' '99' '63' '42'
#  '31' '33' '29' '45' '52' '46' '70' '98' '44' '80' '34' '90' '37' '58'
#  '74' '57' '56' '47' '43' '51' '53']
# combustible :  [3 4 6 5 2 1]
# estufa_chi :  [nan '2' '1']
# eli_basura :  [3 1 4 2 5 6 7 8]
# lavadero :  [1 2]
# fregadero :  [1 2]
# regadera :  [1 2]
# tinaco_azo :  [1 2]
# cisterna :  [1 2]
# pileta :  [2 1]
# calentador :  [1 2]
# medidor_luz :  [1 2]
# bomba_agua :  [1 2]
# tanque_gas :  [2 1]
# aire_acond :  [2 1]
# calefacc :  [2 1]
# chimenea :  [2 1]
# repar_pard :  [2 1]
# repar_tech :  [2 1]
# repar_agua :  [2 1]
# repar_dren :  [2 1]
# repar_cabl :  [2 1]
# const_dorm :  [2 1]
# const_coci :  [2 1]
# const_bano :  [2 1]
# const_neg :  [2 1]
# tenencia :  [1 4 5 2 3 6]
# tipo_adqui :  [nan '2' '1' '4' '5' '7' '6' '3' '8']
# viv_usada :  [nan '1' '2' '9']
# financia_1 :  [nan '1']
# financia_2 :  [nan '2']
# financia_3 :  [nan '3']
# financia_4 :  [nan '4']
# financia_5 :  [nan '5']
# financia_6 :  [nan '6']
# financia_7 :  [nan '7']
# financia_8 :  [nan '8']
# valor_viv :  [nan '6' '5' '4' '9' '3' '7' '2' '1']
# num_dueno1 :  [nan '01' '02' '03' '08' '04' '06' '05' '07' '15' '09']
# hog_dueno1 :  [nan '1' '2' '3']
# num_dueno2 :  [nan '02' '03' '01' '05' '04' '07' '12' '06']
# hog_dueno2 :  [nan '1' '2' '3']
# escrituras :  [nan '1' '4' '5' '3' '2' '9']
# vend_hered :  [nan '1' '2']
# facul_no1 :  [nan '02' '01' '03' '04']
# facul_nh1 :  [nan '1']
# facul_no2 :  [nan '02' '01' '03' '04']
# facul_nh2 :  [nan '1' '2']
# facul_ne :  [nan '9']
# dispos_no1 :  [nan '02' '01' '03' '04']
# dispos_nh1 :  [nan '1']
# dispos_no2 :  [nan '02' '04' '01' '03']
# dispos_nh2 :  [nan '1' '2']
# dispos_ne :  [nan '9']
# tot_resid :  [ 2  8  4  3  1  6  5  7 12 10  9 11 14 13 19 15 17 20 16 21 18]
# tot_hog :  [1 2 3 4]
# ubica_geo :  [ 10010001  10030001  10050001 ... 320550002 320030001 320370001]
# ageb :  ['028-6' '029-0' '030-3' ... '125-9' '120-6' '122-5']
# tam_loc :  [1 2 3 4]
# est_socio :  [3 4 2 1]
# est_dis :  [  5   6   4   1   2   3  13  14  12  11   7   8   9  10  23  22  21  17
#   16  18  15  19  20  30  28  29  27  25  24  26  36  37  38  35  32  31
#   34  33  43  44  42  39  41  40  49  51  50  52  46  45  48  47  58  57
#   59  54  53  56  55  62  61  63  60  69  68  70  67  64  66  65  77  76
#   78  75  71  72  74  73  83  85  84  82  79  80  81  91  90  92  89  86
#   87  88  99 100  98  97  93  94  96  95 106 107 108 105 102 101 103 104
#  115 116 114 110 111 109 113 112 122 123 124 118 117 121 120 119 129 130
#  131 125 126 128 127 136 137 138 135 133 132 134 145 146 144 140 143 139
#  142 141 153 152 154 151 148 147 149 150 160 161 159 156 155 158 157 166
#  167 168 165 162 163 164 175 176 177 174 170 171 169 173 172 183 184 182
#  178 179 181 180 192 191 190 189 186 185 188 187 198 199 200 194 195 193
#  197 196 206 207 208 205 201 202 204 203 214 213 215 210 209 212 211 223
#  222 224 221 218 217 216 219 220 231 230 232 229 226 225 227 228 237 238
#  239 234 233 235 236]
# upm :  [   10    20    30 ... 81750 81760 81770]
# factor_viv :  [ 163  176  166 ... 1028 1078 1026]

# %%
msno.bar(df_copy)

# %%
df_copy.fillna(value=-1, inplace=True)

# %%
threshold = round(df_copy.shape[0]*.8)
threshold
# Out:
# 46892

# %%
l = []
for column in df_copy.columns:
    na_column =  df_copy[column].value_counts().get(-1)
    if(na_column != None):
        #print(column, ': ', df_copy.shape[0] - na_column, ' - ', threshold)
        if (df_copy.shape[0] - na_column < threshold):
            #print(column, ': ', 'd e l e t e d')
            l.append(column)
# Out:
# antiguedad :  d e l e t e d
# potencia :  d e l e t e d
# estufa_chi :  d e l e t e d
# tipo_adqui :  d e l e t e d
# viv_usada :  d e l e t e d
# financia_1 :  d e l e t e d
# financia_2 :  d e l e t e d
# financia_3 :  d e l e t e d
# financia_4 :  d e l e t e d
# financia_5 :  d e l e t e d
# financia_6 :  d e l e t e d
# financia_7 :  d e l e t e d
# financia_8 :  d e l e t e d
# valor_viv :  d e l e t e d
# num_dueno1 :  d e l e t e d
# hog_dueno1 :  d e l e t e d
# num_dueno2 :  d e l e t e d
# hog_dueno2 :  d e l e t e d
# escrituras :  d e l e t e d
# vend_hered :  d e l e t e d
# facul_no1 :  d e l e t e d
# facul_nh1 :  d e l e t e d
# facul_no2 :  d e l e t e d
# facul_nh2 :  d e l e t e d
# facul_ne :  d e l e t e d
# dispos_no1 :  d e l e t e d
# dispos_nh1 :  d e l e t e d
# dispos_no2 :  d e l e t e d
# dispos_nh2 :  d e l e t e d
# dispos_ne :  d e l e t e d

# %%
len(l)
# Out:
# 30

# %%
df_copy.drop(labels=l, axis=1, inplace=True)

# %%
df_copy.replace(to_replace=-1, value=np.NaN, inplace=True)

# %%
msno.bar(df_copy)

# %%
df_copy.isnull().any().any()
# Out:
# True

# %%
df_copy.dropna(inplace=True)

# %%
msno.bar(df_copy)

# %%
df_copy.isnull().any().any()
# Out:
# False

# %%
df_copy.shape
# Out:
# (50995, 55)

# %%
file = "../../dataframes/enh/enh_clean.csv"

# %%
df_copy.to_csv(file)
